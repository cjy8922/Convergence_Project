# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup
import re
import operator
import time
import datetime
from konlpy.tag import Komoran

# %%
def get_news(sectionid, date): 
    url = "https://news.naver.com/main/ranking/popularDay.nhn?rankingType=popular_day&sectionId=" + str(sectionid) + "&date=" + str(date) 
    resp = requests.get(url) 
    soup = BeautifulSoup(resp.text, "html.parser")
    l = []
    ranking_text = soup.find_all(class_ = 'ranking_text')
    for item in ranking_text:
        d = {}
        d['LinkSrc'] = item.find('a')['href']
        d['Title'] = item.find('a')['title']
        d['Views'] = item.find(class_ = "ranking_view").get_text()
        l.append(d)

    for link in l:
        resp = requests.get("http://news.naver.com" + link['LinkSrc'])
        soup = BeautifulSoup(resp.text, "html.parser")
        content = soup.find(id="articleBodyContents")
        link['Content'] = clean_text(content)
        
    df = pd.DataFrame(l)
    return df

# %%
# text 정제하기
def clean_text(text):
    content = text.get_text()
    cleaned_text = re.sub('[a-zA-Z]', '', content)
    cleaned_text = re.sub('[\{\}\[\]\/?.,;:|\)*~`!^\-_+<>▶▽♡◀━@\#$%&\\\=\(\'\"ⓒ(\n)(\t)]', ' ', cleaned_text)
    cleaned_text = cleaned_text.replace("🇲\u200b🇮\u200b🇱\u200b🇱\u200b🇮\u200b🇪\u200b", "")
    cleaned_text = cleaned_text.replace("오류를 우회하기 위한 함수 추가 ", "")
    cleaned_text = cleaned_text.replace("동영상 뉴스 오류를 우회하기 위한 함수 추가 ", "")
    cleaned_text = cleaned_text.replace("무단전재 및 재배포 금지", "")
    return cleaned_text

# %%
get_news(100, 20200430)
# Out:
#                                               LinkSrc  \
# 0   /main/ranking/read.nhn?rankingType=popular_day...
# 1   /main/ranking/read.nhn?rankingType=popular_day...
# 2   /main/ranking/read.nhn?rankingType=popular_day...
# 3   /main/ranking/read.nhn?rankingType=popular_day...
# 4   /main/ranking/read.nhn?rankingType=popular_day...
# 5   /main/ranking/read.nhn?rankingType=popular_day...
# 6   /main/ranking/read.nhn?rankingType=popular_day...
# 7   /main/ranking/read.nhn?rankingType=popular_day...
# 8   /main/ranking/read.nhn?rankingType=popular_day...
# 9   /main/ranking/read.nhn?rankingType=popular_day...
# 10  /main/ranking/read.nhn?rankingType=popular_day...
# 11  /main/ranking/read.nhn?rankingType=popular_day...
# 12  /main/ranking/read.nhn?rankingType=popular_day...
# 13  /main/ranking/read.nhn?rankingType=popular_day...
# 14  /main/ranking/read.nhn?rankingType=popular_day...
# 15  /main/ranking/read.nhn?rankingType=popular_day...
# 16  /main/ranking/read.nhn?rankingType=popular_day...
# 17  /main/ranking/read.nhn?rankingType=popular_day...
# 18  /main/ranking/read.nhn?rankingType=popular_day...
# 19  /main/ranking/read.nhn?rankingType=popular_day...
# 20  /main/ranking/read.nhn?rankingType=popular_day...
# 21  /main/ranking/read.nhn?rankingType=popular_day...
# 22  /main/ranking/read.nhn?rankingType=popular_day...
# 23  /main/ranking/read.nhn?rankingType=popular_day...
# 24  /main/ranking/read.nhn?rankingType=popular_day...
# 25  /main/ranking/read.nhn?rankingType=popular_day...
# 26  /main/ranking/read.nhn?rankingType=popular_day...
# 27  /main/ranking/read.nhn?rankingType=popular_day...
# 28  /main/ranking/read.nhn?rankingType=popular_day...
# 29  /main/ranking/read.nhn?rankingType=popular_day...
#
#                                          Title    Views  \
# 0         양정숙 오피스텔 문 따려하자...세입자 "누구시죠?" 경찰에 신고  262,101
# 1             "김정은 후임은 누구"…외신들, '백두혈통' 김여정에 주목  204,951
# 2          ‘난 지자체에서 이미 받았는데?’ 긴급재난지원금 얼마 받게 될까  185,271
# 3       내달 전국민 긴급재난지원금 지급…12.2조 규모 2차추경 통과(종합)  172,852
# 4          [속보] 문 대통령 “코로나19 국내 확진자 0명… 국민의 힘”  152,554
# 5                    대한민국 모든 국민, 5월에 재난지원금 받는다  136,934
# 6     정진석 “나한테 김종인 띄워달라더니··· 홍준표는 통합당의 미래 아니다”  118,447
# 7             김정은 열차, 어제 또 원산서 포착…태영호는 "교란" 주장  114,597
# 8                전 국민 재난지원금 받는다…금액, 신청 날짜·방법은?  104,270
# 9                트럼프 방위비분담금 압박에…靑, 이례적 `즉각 반박`  103,636
# 10              또 ‘거래의 기술’ 쓴 트럼프…방위비협상 막히자 꺼냈다   97,762
# 11           박주민-김두관 하루차 이견…당내서도 '부산시장 공천' 갈렸다   97,647
# 12        러시아측, '위중설' 김정은에게 축전…金전용열차는 원산서 또 포착   96,670
# 13                 재난지원금 신청 방법은?…다음 달 11일부터 신청   93,830
# 14              문 대통령 “코로나19 국내 확진자 0명, 국민의 힘"   91,893
# 15              지성호 "김정은 사망 99% 확신…심혈관 수술 후유증"   86,942
# 16        저소득 270만 가구 5월 4일 현금 지급…그외 가구는 13일부터   82,252
# 17                재난지원금, 다음 달 4인 가족 100만 원씩 준다   79,656
# 18           김정은 열차 또 원산서 포착…태영호 "위성 의식한 기만전술"   78,112
# 19           '12조 2000억' 2차 추경 통과…전국민 재난지원금 지급   74,465
# 20          긴급재난지원금 반대한 의원 6人 "우리는 포퓰리즘에 반대했다"   74,351
# 21         [단독] 뉴질랜드 남성 "한국외교관 성추행 왜 제대로 조사않나"   72,829
# 22             오거돈·양정숙 악재에…문 대통령·민주당 지지율 동반 하락   71,070
# 23            김정은 전용 열차, 또 원산서 포착… ‘기만 전술’ 반박도   70,115
# 24              인터넷은행 막으려…109명 이름 하염없이 불렀던 채이배   69,186
# 25          [속보]文대통령 “코로나19 국내 확진자 0명…대한민국의 힘”   68,537
# 26                        표결 불참 84명, 국민은 기억합니다   68,347
# 27              재난지원금 11일부터 신청…석달간 신청 안하면 자동기부   66,986
# 28  트럼프, 방위비협상에 "한국, 많은 돈 내기로"…청와대 "협상중"(종합2보)   64,213
# 29            민주당 지원금 기부릴레이…이재명 ‘기본소득’에 김경수 제동   63,787
#
#                                               Content
# 0                      서울 용산 여동생 명의 고급 오피스텔자물쇠 따고 ...
# 1                        김씨 일가에서 나올 것 확실하지만 선택지 제한...
# 2                      내달 11일부터 온라인 신청  수령은 13일부터 ...
# 3                         1차 추경 뒤 45일만에 2차 추경 처리…연...
# 4                      문재인 대통령이 30일 오전 국가위기관리센터에서 ...
# 5                          머니투데이 김상준  기자    300  2...
# 6                      홍준표 전 자유한국당 대표  연합뉴스미래통합당 정...
# 7                        김정은 국무위원장 전용으로 추정되는 열차가 원...
# 8       동영상 뉴스                   5시 정치부회의  여당 발제 앵...
# 9                      한미 방위비분담금 기싸움4월초  잠정타결  논란에...
# 10                     도널드 트럼프 미국 대통령이 한국이 주한미군 방위...
# 11                        오거돈 전 부산시장 성추문에 이은 양정숙 더...
# 12                     北매체  서신교환 등 업무 동정 지속 보도 통일부...
# 13      동영상 뉴스                      【 앵커멘트 】  그렇다면...
# 14                     문재인 대통령이 30일 코로나19 국내 신규 확진...
# 15                      김일성  김정일 사례 봤을 때 주말 발표할 듯 ...
# 16                     ‘전 국민 긴급재난지원금’ 포함 2차 추경안 국회...
# 17      동영상 뉴스                    전국민 재난지원금  2차 추경...
# 18                        지난 14일 김정은 북한 국무위원장의 원산 ...
# 19      동영상 뉴스                    앵커 모든 국민에게 코로나19...
# 20                     미래통합당 곽상도·김무성·신상진·이종구·장제원·정...
# 21                     인권위 1년 넘게 韓외교관 뉴질랜드 성추행 사건 ...
# 22                      오거돈 전 부산시장의 성추문과 양정숙 당선인의 ...
# 23                        김정은 북한 국무위원장이 지난 11일 이후 ...
# 24                     사진 뉴스1지난 3월 한 차례 부결됐던 인터넷전문...
# 25                      메시지…“선거로 인한 감염 0명”문재인 대통령 ...
# 26                         서울신문 재난지원금 늑장 처리도 모자라 가...
# 27                     국회가 30일 새벽 본회의에서 2차 추가경정예산을...
# 28                        로이터 인터뷰서 합의 기정사실화하며 추가부담...
# 29                     이해찬 더불어민주당 대표와 이인영 원내대표가 29...
